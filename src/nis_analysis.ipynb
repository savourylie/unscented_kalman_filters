# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def ukf_csv_to_arr(filename):
    df = pd.read_csv(filename, header=None)
    arr = df.values.reshape(df.size)
    arr = np.array([x for x in arr.tolist() if x is not None])
    
    return arr

# %%
lidar = ukf_csv_to_arr('nis_lidar.csv')
radar = ukf_csv_to_arr('nis_radar.csv')

# %%
pd.Series(lidar).plot()
plt.axhline(y=5.991, linewidth=2, color = 'k')
plt.show()

pd.Series(radar).plot()
plt.axhline(y=7.815, linewidth=2, color = 'k')
plt.show()

# %%
pd.DataFrame(lidar).describe()
# Out:
#                 0
# count  249.000000
# mean     3.958902
# std      8.359288
# min      0.010336
# 25%      0.718084
# 50%      1.571370
# 75%      3.647890
# max     58.928700

# %%
pd.DataFrame(radar).describe()
# Out:
#                 0
# count  249.000000
# mean     6.427664
# std     19.366750
# min      0.062257
# 25%      1.315530
# 50%      2.635080
# 75%      5.334960
# max    212.219000

# %%
lidar
# Out:
# array([  4.33515000e+00,   4.54062000e+00,   2.72432000e+00,
#          2.36285000e+00,   1.36692000e-01,   7.99252000e+00,
#          1.64939000e+00,   6.09829000e+00,   6.54817000e+00,
#          4.18352000e+00,   2.62618000e+00,   5.14311000e-01,
#          1.11348000e+00,   1.24446000e+00,   2.43608000e-01,
#          1.91143000e-01,   5.38468000e-01,   2.48623000e+00,
#          7.79547000e-01,   1.87486000e+00,   2.49898000e+00,
#          3.65938000e-01,   8.79879000e-01,   3.13860000e+00,
#          2.30890000e+00,   8.99571000e-01,   4.06046000e-01,
#          2.40304000e+00,   9.16756000e-01,   4.67094000e-01,
#          3.17134000e-01,   2.50995000e-01,   4.79745000e-01,
#          2.87291000e-01,   2.94137000e-01,   2.39568000e+00,
#          8.81932000e-01,   3.38228000e-01,   2.52042000e+00,
#          4.19229000e+00,   1.03974000e+00,   1.34185000e+00,
#          3.98496000e+00,   4.16111000e+00,   2.97260000e+00,
#          7.52557000e-01,   8.49324000e-01,   2.03119000e+00,
#          1.03358000e-02,   5.20961000e+00,   1.02756000e+00,
#          2.08197000e+00,   1.00199000e+00,   1.37833000e+00,
#          3.44661000e-01,   1.06910000e+00,   2.28454000e+00,
#          3.86917000e+00,   2.32932000e-02,   6.90841000e-01,
#          1.38330000e-01,   1.86183000e+00,   3.80362000e+00,
#          8.81763000e-01,   1.10447000e+00,   4.86422000e-01,
#          3.24368000e-01,   2.78961000e+00,   8.61570000e-01,
#          7.70203000e-01,   1.31335000e+00,   1.76728000e+00,
#          5.90757000e-01,   7.46764000e-01,   1.73513000e+00,
#          1.40843000e-01,   1.94088000e+00,   1.80668000e-01,
#          7.76449000e+00,   2.33963000e+00,   2.53527000e+00,
#          8.31499000e+00,   3.43114000e+00,   3.68255000e+00,
#          1.26165000e+01,   1.70529000e+01,   1.41861000e+01,
#          4.02513000e+01,   3.80308000e+01,   3.70345000e+01,
#          3.60084000e+01,   1.30909000e+01,   1.75281000e+01,
#          5.82763000e+00,   6.99084000e+00,   1.63311000e+00,
#          1.36335000e+01,   7.22891000e+00,   6.43085000e+00,
#          1.93633000e+00,   8.82083000e-01,   3.71452000e+00,
#          1.79486000e+00,   1.43988000e+00,   2.82426000e+00,
#          7.28694000e-01,   8.39035000e-01,   3.94582000e+00,
#          1.43380000e+00,   3.28315000e+00,   3.72930000e-01,
#          5.04215000e-01,   3.64789000e+00,   1.51790000e+00,
#          7.18084000e-01,   1.93525000e+00,   8.81442000e-01,
#          4.08615000e+00,   1.04074000e-01,   9.36539000e-01,
#          6.01353000e-01,   2.72684000e-01,   2.67838000e+00,
#          4.47703000e-01,   1.69289000e+00,   5.56021000e-01,
#          2.06767000e+00,   2.39589000e+00,   7.35034000e-01,
#          1.67692000e-02,   1.37124000e+00,   6.37160000e-01,
#          1.57137000e+00,   5.07636000e+00,   4.05047000e+00,
#          1.59130000e+00,   1.94311000e+00,   1.44445000e+00,
#          2.77890000e+00,   6.32734000e-01,   9.98618000e-01,
#          2.77360000e-01,   3.03908000e+00,   1.21605000e+00,
#          4.56404000e+00,   5.66303000e-01,   1.24970000e+00,
#          2.19800000e-01,   1.86437000e+00,   1.82356000e-01,
#          5.01745000e+00,   4.64823000e-01,   6.12156000e-01,
#          3.54023000e+00,   3.40008000e+00,   3.35693000e+00,
#          2.99063000e+00,   4.77440000e-01,   1.64397000e+00,
#          3.85962000e+00,   1.58433000e+00,   1.39688000e+00,
#          9.23882000e-01,   1.67540000e+00,   5.49705000e+00,
#          2.16949000e+00,   4.49290000e-01,   1.24424000e+01,
#          1.67007000e+01,   4.56719000e+01,   4.18421000e+01,
#          5.61989000e+01,   5.89287000e+01,   3.74664000e+01,
#          9.97794000e-01,   1.32271000e+01,   4.34060000e+00,
#          4.23552000e-01,   1.01353000e+00,   3.78993000e+00,
#          5.81809000e+00,   3.68384000e+00,   1.17962000e+00,
#          5.21510000e+00,   8.39004000e-01,   6.87145000e+00,
#          3.09752000e+00,   1.53025000e+00,   3.81441000e-01,
#          1.45068000e+00,   1.60212000e-01,   1.30669000e+00,
#          4.19743000e+00,   1.54256000e+00,   6.40801000e+00,
#          1.40148000e+00,   1.13369000e+00,   5.97144000e-02,
#          5.18129000e-01,   2.63483000e+00,   1.54252000e+00,
#          3.10895000e+00,   7.85398000e-02,   2.99769000e-01,
#          7.76130000e-01,   1.10368000e-01,   1.57504000e+00,
#          2.23512000e-01,   3.72331000e+00,   2.05412000e+00,
#          4.19255000e-01,   9.42911000e-01,   1.20430000e+00,
#          3.32657000e-02,   9.38942000e-02,   4.23217000e+00,
#          1.01954000e+00,   2.83140000e-01,   2.10616000e+00,
#          5.54361000e-02,   4.68030000e+00,   2.89234000e+00,
#          1.29842000e+00,   5.99617000e-01,   8.36473000e-01,
#          6.09501000e+00,   7.08721000e-01,   3.28765000e+00,
#          1.08196000e+00,   1.27007000e+00,   1.17394000e+00,
#          7.80122000e-01,   1.86419000e+00,   2.72753000e-01,
#          2.14004000e+00,   7.77239000e+00,   7.02756000e-01,
#          3.71413000e+00,   2.24310000e+00,   1.85808000e+00,
#          8.89842000e-01,   2.71491000e+00,   1.02191000e+00,
#          1.94239000e+00,   6.16657000e-01,   9.06938000e-01,
#          5.52154000e+00,   5.01011000e+00,   5.87360000e-01,
#                     nan])

# %%
[i for i, x in enumerate(lidar.tolist()) if x > 6]
# Out:
# [5,
#  7,
#  8,
#  78,
#  81,
#  84,
#  85,
#  86,
#  87,
#  88,
#  89,
#  90,
#  91,
#  92,
#  94,
#  96,
#  97,
#  98,
#  167,
#  168,
#  169,
#  170,
#  171,
#  172,
#  173,
#  175,
#  185,
#  194,
#  225,
#  235]

# %%
[i for i, x in enumerate(radar.tolist()) if x > 7.8]
# Out:
# [0,
#  1,
#  2,
#  3,
#  4,
#  25,
#  49,
#  69,
#  79,
#  80,
#  81,
#  82,
#  83,
#  85,
#  86,
#  88,
#  89,
#  96,
#  136,
#  168,
#  170,
#  172,
#  174,
#  175,
#  176,
#  177,
#  178,
#  179,
#  191,
#  203,
#  210,
#  241]
